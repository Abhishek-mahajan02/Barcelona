# %% [markdown]
# importing lib

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# reading csv data

# %%
d = pd.read_csv("/content/accidents_2017.csv")

# %%
d.head()
# Out:
#                 Id District Name           Neighborhood Name  \
# 0  2017S008429           Unknown                     Unknown
# 1  2017S007316           Unknown                     Unknown
# 2  2017S010210           Unknown                     Unknown
# 3  2017S006364           Unknown                     Unknown
# 4  2017S004615        Sant Martí  el Camp de l'Arpa del Clot
#
#                                               Street   Weekday      Month  \
# 0  Número 27                                     ...    Friday    October
# 1  Número 3 Zona Franca / Número 50 Zona Franca  ...    Friday  September
# 2  Litoral (Besòs)                               ...    Friday   December
# 3  Número 3 Zona Franca                          ...    Friday       July
# 4  Las Navas de Tolosa                           ...  Thursday        May
#
#    Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0   13     8         Morning              2                 0        2
# 1    1    13         Morning              2                 0        2
# 2    8    21       Afternoon              5                 0        5
# 3   21     2           Night              1                 0        1
# 4   25    14       Afternoon              1                 0        1
#
#    Vehicles involved  Longitude   Latitude
# 0                  2   2.125624  41.340045
# 1                  2   2.120452  41.339426
# 2                  2   2.167356  41.360886
# 3                  2   2.124529  41.337668
# 4                  3   2.185272  41.416365

# %%
d.describe()
# Out:
#                 Day          Hour  Mild injuries  Serious injuries  \
# count  10339.000000  10339.000000   10339.000000      10339.000000
# mean      15.775994     13.811394       1.154174          0.023310
# std        8.763455      5.316490       0.742294          0.163803
# min        1.000000      0.000000       0.000000          0.000000
# 25%        8.000000     10.000000       1.000000          0.000000
# 50%       16.000000     14.000000       1.000000          0.000000
# 75%       23.000000     18.000000       1.000000          0.000000
# max       31.000000     23.000000      10.000000          4.000000
#
#             Victims  Vehicles involved     Longitude      Latitude
# count  10339.000000       10339.000000  10339.000000  10339.000000
# mean       1.178644           1.920979      2.162832     41.399346
# std        0.735145           0.714011      0.024176      0.021251
# min        0.000000           0.000000      2.091855     41.323094
# 25%        1.000000           2.000000      2.144985     41.386288
# 50%        1.000000           2.000000      2.163399     41.396730
# 75%        1.000000           2.000000      2.180179     41.411038
# max       10.000000          14.000000      2.222572     41.468244

# %%
list(d)
# Out:
# ['Id',
#  'District Name',
#  'Neighborhood Name',
#  'Street',
#  'Weekday',
#  'Month',
#  'Day',
#  'Hour',
#  'Part of the day',
#  'Mild injuries',
#  'Serious injuries',
#  'Victims',
#  'Vehicles involved',
#  'Longitude',
#  'Latitude']

# %%
d1 = d['Weekday'].value_counts()
d1 = pd.DataFrame(d1)
d1
# Out:
#            Weekday
# Friday        1761
# Tuesday       1691
# Thursday      1677
# Wednesday     1650
# Monday        1510
# Saturday      1155
# Sunday         895

# %%
d1 = d1 / sum(d1['Weekday'])

# %%
d1
# Out:
#             Weekday
# Friday     0.170326
# Tuesday    0.163555
# Thursday   0.162201
# Wednesday  0.159590
# Monday     0.146049
# Saturday   0.111713
# Sunday     0.086565

# %%
d1.sort_values( by ='Weekday')
# Out:
#             Weekday
# Sunday     0.086565
# Saturday   0.111713
# Monday     0.146049
# Wednesday  0.159590
# Thursday   0.162201
# Tuesday    0.163555
# Friday     0.170326

# %%
d1 = d1 * 100

# %%
d1
# Out:
#              Weekday
# Friday     17.032595
# Tuesday    16.355547
# Thursday   16.220137
# Wednesday  15.958990
# Monday     14.604894
# Saturday   11.171293
# Sunday      8.656543

# %%
std = np.std(d1['Weekday']) #calculating standard deviation

# %%
std
# Out:
# 2.924294005636336

# %%
mean = np.mean(d1['Weekday'])

# %%
d1 = d1 - mean

# %%
d1/std
# Out:
#             Weekday
# Friday     0.939331
# Tuesday    0.707806
# Thursday   0.661501
# Wednesday  0.572198
# Monday     0.109148
# Saturday  -1.065016
# Sunday    -1.924968

# %%
d2 = d.iloc[:,[4,8]]  #iloc helping in selecting particular cell weekday and part of the day 
d2.head()
# Out:
#     Weekday Part of the day
# 0    Friday         Morning
# 1    Friday         Morning
# 2    Friday       Afternoon
# 3    Friday           Night
# 4  Thursday       Afternoon

# %%
d3 = d2.loc[d2['Weekday'] == 'Friday']

# %%
d3.head()
# Out:
#    Weekday Part of the day
# 0   Friday         Morning
# 1   Friday         Morning
# 2   Friday       Afternoon
# 3   Friday           Night
# 12  Friday         Morning

# %%
pd.unique(d['Part of the day'])
# Out:
# array(['Morning', 'Afternoon', 'Night'], dtype=object)

# %%
d4 = d3['Part of the day'].value_counts()

# %%
d4
d4 = pd.DataFrame(d4)
d4
# Out:
#            Part of the day
# Afternoon              884
# Morning                707
# Night                  170

# %%
d4 = d4 / sum(d4['Part of the day'])
d4 = d4 * 100
d4
# Out:
#            Part of the day
# Afternoon        50.198751
# Morning          40.147643
# Night             9.653606

# %%
d5 = d.iloc[:, 8]
d5.head()
# Out:
# 0      Morning
# 1      Morning
# 2    Afternoon
# 3        Night
# 4    Afternoon
# Name: Part of the day, dtype: object

# %%
d5 = d5.value_counts()
d5 = pd.DataFrame(d5)
d5
ei = d5
ei
# Out:
#            Part of the day
# Afternoon             5082
# Morning               4067
# Night                 1190

# %%
d5 = d5 / sum(d5['Part of the day'])
d5 = d5 * 100
d5
# Out:
#            Part of the day
# Afternoon        49.153690
# Morning          39.336493
# Night            11.509817

# %%
d6 = d2.loc[d2['Weekday'] == 'Tuesday']
d6 = d6['Part of the day'].value_counts()
d6 = pd.DataFrame(d6)
d6
# Out:
#            Part of the day
# Afternoon              815
# Morning                739
# Night                  137

# %%
d6 = d6 / sum(d6['Part of the day'])
d6 = d6 * 100
d6
# Out:
#            Part of the day
# Afternoon        48.196334
# Morning          43.701952
# Night             8.101715

# %%
d7 = d.iloc[:, 6]
d7 = pd.DataFrame(d7)
d7.head()
# Out:
#    Day
# 0   13
# 1    1
# 2    8
# 3   21
# 4   25

# %%
w1 = d7.loc[d7['Day']<=7]
w2 = d7.loc[(d7['Day']>7) & (d7['Day']<=14)]
w3 = d7.loc[(d7['Day']>14) & (d7['Day']<=21)]
w4 = d7.loc[(d7['Day']>21) & (d7['Day']<=31)]
w1 = w1.describe()
w4.describe()
# Out:
#                Day
# count  3143.000000
# mean     26.318804
# std       2.789140
# min      22.000000
# 25%      24.000000
# 50%      26.000000
# 75%      29.000000
# max      31.000000

# %%
w1
# Out:
#                Day
# count  2342.000000
# mean      3.974381
# std       1.955557
# min       1.000000
# 25%       2.000000
# 50%       4.000000
# 75%       6.000000
# max       7.000000

# %%
w2
# Out:
#        Day
# 0       13
# 2        8
# 8       12
# 10      14
# 11      11
# ...    ...
# 10332   10
# 10333    8
# 10335    8
# 10337   14
# 10338    8
#
# [2346 rows x 1 columns]

# %%
w3
# Out:
#        Day
# 3       21
# 5       20
# 6       20
# 15      17
# 19      17
# ...    ...
# 10322   21
# 10327   21
# 10328   21
# 10330   16
# 10331   20
#
# [2508 rows x 1 columns]

# %%
w4
# Out:
#        Day
# 4       25
# 7       26
# 12      30
# 14      30
# 16      25
# ...    ...
# 10323   22
# 10324   26
# 10326   31
# 10334   25
# 10336   28
#
# [3143 rows x 1 columns]

# %%
w = w1 + w2 + w3 + w4
w1 = w1 / w
w1 = w1 * 100
w2 = w2 / w
w2 = w2 * 100
w3 = w3 / w
w3 = w3 * 100
w4 = w4 / w
w4 = w4 * 100

# %%
w1
# Out:
#        Day
# 0      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# ...    ...
# count  NaN
# max    NaN
# mean   NaN
# min    NaN
# std    NaN
#
# [8005 rows x 1 columns]

# %%
w2
# Out:
#        Day
# 0      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# ...    ...
# count  NaN
# max    NaN
# mean   NaN
# min    NaN
# std    NaN
#
# [8005 rows x 1 columns]

# %%
w3
# Out:
#        Day
# 0      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# ...    ...
# count  NaN
# max    NaN
# mean   NaN
# min    NaN
# std    NaN
#
# [8005 rows x 1 columns]

# %%
w4
# Out:
#        Day
# 0      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# ...    ...
# count  NaN
# max    NaN
# mean   NaN
# min    NaN
# std    NaN
#
# [8005 rows x 1 columns]

# %%
e1 = d.loc[d['Serious injuries']!=0]

# %%
e1.head()
# Out:
#                   Id District Name                      Neighborhood Name  \
# 13   2017S007384        Sant Martí             el Camp de l'Arpa del Clot
# 21   2017S007805        Sant Martí             el Camp de l'Arpa del Clot
# 30   2017S007303        Sant Martí             el Camp de l'Arpa del Clot
# 211  2017S004804      Ciutat Vella  Sant Pere, Santa Caterina i la Ribera
# 307  2017S009133          Eixample                            Sant Antoni
#
#                                                 Street    Weekday      Month  \
# 13   Sant Antoni Maria Claret                      ...     Monday  September
# 21   València / Independència                      ...  Wednesday  September
# 30   València                                      ...   Thursday     August
# 211  Colom / Antonio López                         ...  Wednesday        May
# 307  Muntaner                                      ...     Sunday   November
#
#      Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 13     4    16       Afternoon              0                 1        1
# 21    20    20       Afternoon              0                 1        1
# 30    31    21       Afternoon              0                 1        1
# 211   31    22           Night              0                 1        1
# 307    5     0           Night              0                 1        1
#
#      Vehicles involved  Longitude   Latitude
# 13                   2   2.176324  41.412546
# 21                   2   2.183407  41.407785
# 30                   1   2.185811  41.409730
# 211                  2   2.181974  41.381016
# 307                  1   2.162809  41.384192

# %%
e2 = e1['Part of the day'].value_counts()
type(e2)
e2 = pd.DataFrame(e2)
e2 = e2 / sum(e2['Part of the day'])
e2 = e2 * 100
e2
# Out:
#            Part of the day
# Afternoon        50.224215
# Morning          32.735426
# Night            17.040359

# %%
e1 = e1.iloc[:, [1,3,4,6,7,8,10]]
e1.head()
# Out:
#     District Name                                             Street  \
# 13     Sant Martí  Sant Antoni Maria Claret                      ...
# 21     Sant Martí  València / Independència                      ...
# 30     Sant Martí  València                                      ...
# 211  Ciutat Vella  Colom / Antonio López                         ...
# 307      Eixample  Muntaner                                      ...
#
#        Weekday  Day  Hour Part of the day  Serious injuries
# 13      Monday    4    16       Afternoon                 1
# 21   Wednesday   20    20       Afternoon                 1
# 30    Thursday   31    21       Afternoon                 1
# 211  Wednesday   31    22           Night                 1
# 307     Sunday    5     0           Night                 1

# %%
e2
# Out:
#            Part of the day
# Afternoon        50.224215
# Morning          32.735426
# Night            17.040359

# %%
d5
# Out:
#            Part of the day
# Afternoon        49.153690
# Morning          39.336493
# Night            11.509817

# %%
ei
# Out:
#            Part of the day
# Afternoon             5082
# Morning               4067
# Night                 1190

# %%
data = pd.read_csv("/content/accidents_2017.csv")
data.head(30)
# Out:
#                  Id District Name           Neighborhood Name  \
# 0   2017S008429           Unknown                     Unknown
# 1   2017S007316           Unknown                     Unknown
# 2   2017S010210           Unknown                     Unknown
# 3   2017S006364           Unknown                     Unknown
# 4   2017S004615        Sant Martí  el Camp de l'Arpa del Clot
# 5   2017S007775        Sant Martí  el Camp de l'Arpa del Clot
# 6   2017S004484        Sant Martí  el Camp de l'Arpa del Clot
# 7   2017S010680        Sant Martí  el Camp de l'Arpa del Clot
# 8   2017S005152        Sant Martí  el Camp de l'Arpa del Clot
# 9   2017S003932        Sant Martí  el Camp de l'Arpa del Clot
# 10  2017S010348        Sant Martí  el Camp de l'Arpa del Clot
# 11  2017S000245        Sant Martí  el Camp de l'Arpa del Clot
# 12  2017S005695        Sant Martí  el Camp de l'Arpa del Clot
# 13  2017S007384        Sant Martí  el Camp de l'Arpa del Clot
# 14  2017S008080        Sant Martí  el Camp de l'Arpa del Clot
# 15  2017S003439        Sant Martí  el Camp de l'Arpa del Clot
# 16  2017S002410        Sant Martí  el Camp de l'Arpa del Clot
# 17  2017S009296        Sant Martí  el Camp de l'Arpa del Clot
# 18  2017S010102        Sant Martí  el Camp de l'Arpa del Clot
# 19  2017S002158        Sant Martí  el Camp de l'Arpa del Clot
# 20  2017S007606        Sant Martí  el Camp de l'Arpa del Clot
# 21  2017S007805        Sant Martí  el Camp de l'Arpa del Clot
# 22  2017S008987        Sant Martí  el Camp de l'Arpa del Clot
# 23  2017S002244        Sant Martí  el Camp de l'Arpa del Clot
# 24  2017S001012        Sant Martí  el Camp de l'Arpa del Clot
# 25  2017S009722        Sant Martí  el Camp de l'Arpa del Clot
# 26  2017S001895        Sant Martí  el Camp de l'Arpa del Clot
# 27  2017S008277        Sant Martí  el Camp de l'Arpa del Clot
# 28  2017S004380        Sant Martí  el Camp de l'Arpa del Clot
# 29  2017S001233        Sant Martí  el Camp de l'Arpa del Clot
#
#                                                Street    Weekday      Month  \
# 0   Número 27                                     ...     Friday    October
# 1   Número 3 Zona Franca / Número 50 Zona Franca  ...     Friday  September
# 2   Litoral (Besòs)                               ...     Friday   December
# 3   Número 3 Zona Franca                          ...     Friday       July
# 4   Las Navas de Tolosa                           ...   Thursday        May
# 5   Indústria / Trinxant                          ...  Wednesday  September
# 6   Trinxant / Indústria                          ...   Saturday        May
# 7   Indústria                                     ...    Tuesday   December
# 8   Indústria                                     ...     Monday       June
# 9   Maragall                                      ...  Wednesday        May
# 10  Indústria                                     ...   Thursday   December
# 11  ST ANTONI M CLARET / Pg Maragall              ...  Wednesday    January
# 12  Sant Antoni Maria Claret / Guinardó           ...     Friday       June
# 13  Sant Antoni Maria Claret                      ...     Monday  September
# 14  Sant Antoni Maria Claret                      ...   Saturday  September
# 15  Còrsega / Còrsega                             ...     Monday      April
# 16  CÒRSEGA / Dos de Maig                         ...   Saturday      March
# 17  Indústria                                     ...   Thursday   November
# 18  Rosselló / Independència                      ...     Monday   December
# 19  VALÈNCIA                                      ...     Friday      March
# 20  València                                      ...   Thursday  September
# 21  València / Independència                      ...  Wednesday  September
# 22  València                                      ...     Monday    October
# 23  ARAGÓ / Corunya                               ...     Monday      March
# 24  MALLORCA                                      ...    Tuesday   February
# 25  Mallorca                                      ...  Wednesday   November
# 26  DOS DE MAIG / Mallorca                        ...  Wednesday      March
# 27  Mallorca / Dos de Maig                        ...   Saturday    October
# 28  València / Independència                      ...  Wednesday        May
# 29  VALÈNCIA                                      ...    Tuesday   February
#
#     Day  Hour Part of the day  Mild injuries  Serious injuries  Victims  \
# 0    13     8         Morning              2                 0        2
# 1     1    13         Morning              2                 0        2
# 2     8    21       Afternoon              5                 0        5
# 3    21     2           Night              1                 0        1
# 4    25    14       Afternoon              1                 0        1
# 5    20    12         Morning              1                 0        1
# 6    20    21       Afternoon              1                 0        1
# 7    26    20       Afternoon              2                 0        2
# 8    12    15       Afternoon              1                 0        1
# 9     3    20       Afternoon              1                 0        1
# 10   14    20       Afternoon              1                 0        1
# 11   11     7         Morning              1                 0        1
# 12   30    12         Morning              1                 0        1
# 13    4    16       Afternoon              0                 1        1
# 14   30    19       Afternoon              1                 0        1
# 15   17    14       Afternoon              1                 0        1
# 16   25    14       Afternoon              4                 0        4
# 17    9    22           Night              1                 0        1
# 18    4     0           Night              2                 0        2
# 19   17    16       Afternoon              1                 0        1
# 20   14    14       Afternoon              1                 0        1
# 21   20    20       Afternoon              0                 1        1
# 22   30    20       Afternoon              1                 0        1
# 23   20    19       Afternoon              1                 0        1
# 24    7    11         Morning              1                 0        1
# 25   22    20       Afternoon              1                 0        1
# 26    8    12         Morning              1                 0        1
# 27    7     6         Morning              2                 0        2
# 28   17    13         Morning              0                 0        0
# 29   14    16       Afternoon              1                 0        1
#
#     Vehicles involved  Longitude   Latitude
# 0                   2   2.125624  41.340045
# 1                   2   2.120452  41.339426
# 2                   2   2.167356  41.360886
# 3                   2   2.124529  41.337668
# 4                   3   2.185272  41.416365
# 5                   2   2.183245  41.416336
# 6                   2   2.183245  41.416336
# 7                   1   2.183561  41.416372
# 8                   1   2.184059  41.416763
# 9                   1   2.181225  41.413958
# 10                  2   2.182290  41.415772
# 11                  2   2.180453  41.415790
# 12                  2   2.181140  41.416295
# 13                  2   2.176324  41.412546
# 14                  2   2.176324  41.412546
# 15                  2   2.178314  41.410784
# 16                  2   2.177719  41.410323
# 17                  1   2.176740  41.411445
# 18                  2   2.180100  41.410287
# 19                  2   2.184855  41.408993
# 20                  2   2.154877  41.386210
# 21                  2   2.183407  41.407785
# 22                  2   2.184033  41.408102
# 23                  2   2.185732  41.407803
# 24                  1   2.181775  41.408393
# 25                  2   2.181955  41.408529
# 26                  2   2.181123  41.407749
# 27                  4   2.181123  41.407749
# 28                  2   2.183407  41.407785
# 29                  1   2.185751  41.409684

# %%
category=data['Weekday'].value_counts()
plt.figure(figsize=[20,5])
x=category[:15].index
y=category[:15].values
sns.barplot(x, y)
plt.xlabel('days')
plt.ylabel('Number of accidents on that day')
plt.title('Accident per day')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Accident per day')

# %%
category=data['Part of the day'].value_counts()
plt.figure(figsize=[20,5])
x=category[:15].index
y=category[:15].values
sns.barplot(x, y)
plt.xlabel('Part of the day')
plt.ylabel('Number of accidents')
plt.title('Accident by Part of the day')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Accident by Part of the day')

# %%
category=data['Street'].value_counts()
plt.figure(figsize=[20,5])
x=category[:15].index
y=category[:15].values
sns.barplot(x, y)
plt.xlabel('street')
plt.ylabel('Number of accidents in that street')
plt.title('Accident by street')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Accident by street')

# %%
category
# Out:
# Corts Catalanes                                       219
# Diagonal                                              176
# Litoral (Llobregat)                                   116
# Litoral (Besòs)                                        99
# Aragó                                                  95
#                                                      ...
# Pintor Alsamora                                         1
# Deià / Andratx                                          1
# Garrofers                                               1
# Doctor Pi i Molist / Alcúdia                            1
# PL MONTERREY                                            1
# Name: Street, Length: 4253, dtype: int64

# %%
category=data['District Name'].value_counts()
plt.figure(figsize=[20,5])
x=category[:15].index
y=category[:15].values
sns.barplot(x, y)
plt.xlabel('District Name')
plt.ylabel('Number of accidents in that district')
plt.title('Accident by district')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Accident by district')

# %%
category=data['Month'].value_counts()
plt.figure(figsize=[12,5])
x=category[:15].index
y=category[:15].values
sns.barplot(x, y)
plt.xlabel('months')
plt.ylabel('number of accident')
plt.title('accident numbers by month')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'accident numbers by month')

# %%
category=data['Hour'].value_counts()
plt.figure(figsize=[12,5])
x=category[:15].index
y=category[:15].values
sns.barplot(x, y)
plt.xlabel('hours')
plt.ylabel('number of accident')
plt.title('accident numbers by hour')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'accident numbers by hour')

# %%
category=data['Month'].value_counts()
plt.figure(figsize=[12,5])
x=category[:15].index
y=category[:15].values
sns.barplot(x, y)
plt.xlabel('months')
plt.ylabel('number of accident')
plt.title('accident numbers by month')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'accident numbers by month')

# %%
max_long, max_lat, min_long, min_lat=max(data['Longitude'].values), max(data['Latitude'].values), min(data['Longitude'].values), min(data['Latitude'].values)
print(max_long, min_long, max_lat, min_lat)
# Out:
# 2.222572 2.091855 41.468244 41.323094

# %%
map_of_barcelona=np.zeros((542, 431), dtype=int) 

area=(min_long, max_lat, max_long, min_lat)

# %%
def Street_map(data, area, map_of_barcelona, s=10):#using longtitude and latitude on map
    fig, axs = plt.subplots(figsize=(30, 25))
    datafilter=data[data['Hour']>12]
    datafilter2=data[data['Hour']<=12]
    axs.scatter(datafilter.Longitude, datafilter.Latitude, alpha=1, color='red', label="Afternoon")
    axs.scatter(datafilter2.Longitude, datafilter2.Latitude, alpha=1,  color='blue', label="Before noon")
    axs.set_xlim(area[0], area[2])
    axs.set_ylim((area[3], area[1]))
    axs.set_title('accident points on map')
    axs.imshow(map_of_barcelona, zorder=1, extent=area)
Street_map(data, area, map_of_barcelona)

# %%
import seaborn as sns
sns.pairplot(data)

# %%
corr = data.corr()

plt.figure(figsize=(18, 15))
sns.heatmap(corr, annot=True, vmin=-1.0, cmap='mako')
plt.title("Correlation Heatmap")
plt.show()
